# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install deeplabcut
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 47.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.8 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=c2de66a128a80785202f3fbb1992b20a21405aa8ac081de10e856d81f0e219e1
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
# Successfully built filterpy
# ...
#   Attempting uninstall: torch
# ...

# %%
import deeplabcut
# Out:
# Loading DLC 2.3.5...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
# %cd /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04
! ls
# Out:
# /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04
# config.yaml  evaluation-results  training-datasets
# dlc-models   labeled-data	 videos

# %%
config_path = "/content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/config.yaml"

# %%
 deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by ruoqi.
# 100%|██████████| 20/20 [00:03<00:00,  5.59it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %%
 deeplabcut.create_training_dataset(config_path, num_shuffles=1)
# Out:
# ...
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# [(0.95,
#   1,
#   (array([18,  1, 19,  8, 10, 17,  6, 13,  4,  2,  5, 14,  9,  7, 16, 11,  3,
#            0, 15]),
#    array([12])))]

# %%
deeplabcut.train_network(config_path,shuffle=1, displayiters=100,saveiters=500, maxiters=20000)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3]],
#  'all_joints_names': ['head', 'body', 'tail', ''],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'contrast': {'clahe': True,
#               'claheratio': 0.1,
#               'histeq': True,
#               'histeqratio': 0.1},
#  'convolution': {'edge': False,
#                  'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]},
#                  'embossratio': 0.1,
#                  'sharpen': False,
#                  'sharpenratio': 0.3},
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_test2Aug4/test2_ruoqi95shuffle1.mat',
#  'dataset_type': 'default',
#  'decay_steps': 30000,
#  'deterministic': False,
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': '/usr/local/lib/python3.10/dist-packages/deeplabcut/pose_estimation_tensorflow/models/pretrained/resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
# ...

# %%
 # %matplotlib notebook
 deeplabcut.evaluate_network(config_path, plotting=True)
# Out:
# Running  DLC_resnet50_test2Aug4shuffle1_72500  with # of training iterations: 72500
# This net has already been evaluated!
# Plots already exist for this snapshot... Skipping to the next one.

# %%
# !pip install tables==3.7.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 14.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tables
#     Found existing installation: tables 3.8.0
#     Uninstalling tables-3.8.0:
#       Successfully uninstalled tables-3.8.0
# ...

# %%
deeplabcut.analyze_videos(config_path,['/content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos'], save_as_csv=True, videotype='.mp4')
# Out:
# Using snapshot-72500 for model /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/dlc-models/iteration-0/test2Aug4-trainset95shuffle1
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Analyzing all the videos in the directory...
# Starting to analyze %  /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f2.mp4
# Loading  /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f2.mp4
# Starting to analyze %  /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f1.mp4
# Loading  /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f1.mp4
# Starting to analyze %  /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f3.mp4
# ...

# %%
deeplabcut.create_labeled_video(config_path,['/content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f2.mp4'])
# Out:
# Starting to process video: /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f2.mp4
# Loading /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/f2.mp4 and data.
# No unfiltered data file found in /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos for video f2 and scorer DLC_resnet50_test2Aug4shuffle1_72500.
# [False]

# %%
deeplabcut.create_labeled_video(config_path,['/content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos'],save_frames=True)
# Out:
# Analyzing all the videos in the directory...
# Starting to process video: /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/Basler_acA640-750um__24510410__20230807_111151898.mp4Starting to process video: /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/Basler_acA640-750um__24510410__20230807_105445454.mp4
# Loading /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/Basler_acA640-750um__24510410__20230807_105445454.mp4 and data.
#
# Loading /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/Basler_acA640-750um__24510410__20230807_111151898.mp4 and data.No unfiltered data file found in /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos for video Basler_acA640-750um__24510410__20230807_105445454 and scorer DLC_resnet50_test2Aug4shuffle1_72500.
# Starting to process video: /content/drive/MyDrive/Colab Deeplabcut/f1test-cai-2023-08-07/videos/Basler_acA640-750um__24510410__20230807_110026373.mp4
#
# ...

# %%
https://github.com/DeepLabCut/DeepLabCut/blob/3c3804dbefdadd901098d99dee582e2f5bebd687/docs/functionDetails.md#i-novel-video-analysis-extra-features
