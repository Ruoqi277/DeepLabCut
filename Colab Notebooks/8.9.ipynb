# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/N-c-2023-08-09
# !ls
# Out:
# /content/drive/MyDrive/N-c-2023-08-09
# config.yaml  labeled-data  videos

# %%
# !pip install deeplabcut
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 40.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.3 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=600a9d2f9701e8f8543ade19d4c33c4d99cb56a7e27ce10ca271defe14b0b639
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
# Successfully built filterpy
# ...
#   Attempting uninstall: torch
# ...

# %%
import deeplabcut
# Out:
# Loading DLC 2.3.5...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
config_file = '/content/drive/MyDrive/N-c-2023-08-09/config.yaml'

# %%
deeplabcut.load_demo_data(config_file)
# Out:
# This is not an official demo dataset.
# Loaded, now creating training data...
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!

# %%
deeplabcut.train_network(config_file, shuffle=1, displayiters=100,saveiters=500, maxiters=10000)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6]],
#  'all_joints_names': ['leftleg1',
#                       'leftleg2',
#                       'leftleg3',
#                       'rightleg1',
#                       'rightleg2',
#                       'rightleg3',
#                       'abdomen'],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'contrast': {'clahe': True,
#               'claheratio': 0.1,
#               'histeq': True,
#               'histeqratio': 0.1},
#  'convolution': {'edge': False,
#                  'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]},
#                  'embossratio': 0.1,
#                  'sharpen': False,
#                  'sharpenratio': 0.3},
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_NAug9/N_c95shuffle1.mat',
#  'dataset_type': 'imguag',
#  'decay_steps': 30000,
#  'deterministic': False,
#  'display_iters': 1000,
# ...
