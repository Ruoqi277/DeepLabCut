# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install deeplabcut

# %%
import deeplabcut
# Out:
# Loading DLC 2.3.5...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
ProjectFolderName = 'Colab Deeplabcut/test2-ruoqi-2023-08-04'

path_config_file = '/content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/config.yaml'

# Set video type
# ! for different projects, the video types could be different. Make sure the type is correct!
VideoType = 'avi'

# Set video path
# ! make sure the video path contains the video file name. For example, in this project, m3v1mp4.mp4
videofile_path = ['/content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos/Group_42022-07-23T11_40_24.avi'] #Enter the list of videos or folder

# %%
deeplabcut.create_training_dataset(path_config_file, net_type='resnet_50', augmenter_type='imgaug')
# Out:
# ...
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# [(0.95,
#   1,
#   (array([18,  1, 19,  8, 10, 17,  6, 13,  4,  2,  5, 14,  9,  7, 16, 11,  3,
#            0, 15]),
#    array([12])))]

# %%
deeplabcut.train_network(path_config_file, shuffle=1, displayiters=100, saveiters=500)
# Out:
# Selecting single-animal trainer
# Config:
# {'all_joints': [[0], [1], [2], [3]],
#  'all_joints_names': ['head', 'body', 'tail', ''],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'contrast': {'clahe': True,
#               'claheratio': 0.1,
#               'histeq': True,
#               'histeqratio': 0.1},
#  'convolution': {'edge': False,
#                  'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]},
#                  'embossratio': 0.1,
#                  'sharpen': False,
#                  'sharpenratio': 0.3},
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_test2Aug4/test2_ruoqi95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'decay_steps': 30000,
#  'deterministic': False,
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': '/usr/local/lib/python3.10/dist-packages/deeplabcut/pose_estimation_tensorflow/models/pretrained/resnet_v1_50.ckpt',
# ...

# %%
# %matplotlib notebook
deeplabcut.evaluate_network(path_config_file,plotting=True)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3]],
#  'all_joints_names': ['head', 'body', 'tail', ''],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_test2Aug4/test2_ruoqi95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': '/usr/local/lib/python3.10/dist-packages/deeplabcut/pose_estimation_tensorflow/models/pretrained/resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 4,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
# ...

# %%
videofile_path = ['/content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos/Group_42022-07-23T11_40_24.avi'] #Enter the list of videos to analyze.
deeplabcut.analyze_videos(path_config_file,videofile_path, shuffle = 1, save_as_csv=True,videotype='.avi',)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3]],
#  'all_joints_names': ['head', 'body', 'tail', ''],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_test2Aug4/test2_ruoqi95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': '/usr/local/lib/python3.10/dist-packages/deeplabcut/pose_estimation_tensorflow/models/pretrained/resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 4,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
# ...

# %%
deeplabcut.create_labeled_video(path_config_file,videofile_path)
# Out:
# Starting to process video: /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos/Group_42022-07-23T11_40_24.avi
# Loading /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos/Group_42022-07-23T11_40_24.avi and data.
# No unfiltered data file found in /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos for video Group_42022-07-23T11_40_24 and scorer DLC_resnet50_test2Aug4shuffle1_72500.
# [False]

# %%
deeplabcut.plot_trajectories(path_config_file,videofile_path)
# Out:
# Loading  /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos/Group_42022-07-23T11_40_24.avi and data.
# No unfiltered data file found in /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos for video Group_42022-07-23T11_40_24 and scorer DLC_resnet50_test2Aug4shuffle1_72500.
# Plots could not be created for /content/drive/MyDrive/Colab Deeplabcut/test2-ruoqi-2023-08-04/videos/Group_42022-07-23T11_40_24.avi. Videos were not evaluated with the current scorer DLC_resnet50_test2Aug4shuffle1_72500.
