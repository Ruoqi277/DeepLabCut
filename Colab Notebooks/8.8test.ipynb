# %%
# !git clone -l -s https://github.com/Ruoqi277/DeepLabCut.git cloned-f1test
# Out:
# Cloning into 'cloned-f1test'...
# ...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 87 (delta 1), reused 0 (delta 0), pack-reused 81
# Receiving objects: 100% (87/87), 31.61 MiB | 26.34 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# %cd /content/cloned-f1test
# !ls
# Out:
# /content/cloned-f1test
#  8_7f1test.py		      README.md
#  Colab_DEMO_mouse_openfield  'Screenshot 2023-08-08 132439.png'
#  f1test-20223-8-8

# %%
# %cd /content/cloned-f1test/f1test-20223-8-8
# Out:
# /content/cloned-f1test/f1test-20223-8-8

# %%
# !ls
# Out:
# config.yaml  labeled-data  videos

# %%
# !pip install deeplabcut
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 44.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.8 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=d0b97cbf139e678681ccf70dba4318a8177a6abbd0423f2f1f88d79d910d4f37
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
# Successfully built filterpy
# ...
#   Attempting uninstall: torch
# ...

# %%
import deeplabcut
# Out:
# Loading DLC 2.3.5...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
config_file = '/content/cloned-f1test/f1test-20223-8-8/config.yaml'

# %%
deeplabcut.load_demo_data(config_file)
# Out:
# This is not an official demo dataset.
# Loaded, now creating training data...
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!

# %%
//deeplabcut.create_training_dataset(config_file, net_type='resnet_50', augmenter_type='imgaug')
# Out:
#   File "<ipython-input-5-4a807e69cf53>", line 1
#     //deeplabcut.create_training_dataset(config_file, net_type='resnet_50', augmenter_type='imgaug')
#     ^
# SyntaxError: invalid syntax

# %%
deeplabcut.train_network(config_file, shuffle=1, displayiters=100,saveiters=500, maxiters=10000)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['head',
#                       'leftleg1',
#                       'leftleg2',
#                       'leftleg3',
#                       'rightleg1',
#                       'rightleg2',
#                       'rightleg3',
#                       'tail'],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'contrast': {'clahe': True,
#               'claheratio': 0.1,
#               'histeq': True,
#               'histeqratio': 0.1},
#  'convolution': {'edge': False,
#                  'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]},
#                  'embossratio': 0.1,
#                  'sharpen': False,
#                  'sharpenratio': 0.3},
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_f1testAug7/f1test_cai95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'decay_steps': 30000,
#  'deterministic': False,
# ...

# %%
# %matplotlib notebook
deeplabcut.evaluate_network(config_file,plotting=True)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['head',
#                       'leftleg1',
#                       'leftleg2',
#                       'leftleg3',
#                       'rightleg1',
#                       'rightleg2',
#                       'rightleg3',
#                       'tail'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_f1testAug7/f1test_cai95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': '/usr/local/lib/python3.10/dist-packages/deeplabcut/pose_estimation_tensorflow/models/pretrained/resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
# ...

# %%
videofile_path = ['/content/cloned-f1test/f1test-20223-8-8/videos/f1.mp4.mp4'] #Enter the list of videos to analyze.
deeplabcut.analyze_videos(config_file,videofile_path,save_as_csv = True, videotype='.mp4')
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['head',
#                       'leftleg1',
#                       'leftleg2',
#                       'leftleg3',
#                       'rightleg1',
#                       'rightleg2',
#                       'rightleg3',
#                       'tail'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_f1testAug7/f1test_cai95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': '/usr/local/lib/python3.10/dist-packages/deeplabcut/pose_estimation_tensorflow/models/pretrained/resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
# ...

# %%
deeplabcut.create_labeled_video(config_file,videofile_path,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a76b761388c6> in <cell line: 1>()
# ----> 1 deeplabcut.create_labeled_video(config_file,videofile_path,save_as_csv = True)
#
# TypeError: create_labeled_video() got an unexpected keyword argument 'save_as_csv'

# %%
deeplabcut.plot_trajectories(config_file,videofile_path)
# Out:
# Loading  /content/cloned-f1test/f1test-20223-8-8/videos/f1.mp4.mp4 and data.
# <div id='8dc79422-cc84-4d2b-99b6-ca64773d5051'></div>
# <div id='5cf22ecf-29d6-4acf-93f0-b38c1e664ab8'></div>
# <div id='ac95807a-2bbf-4954-bf9a-646530440365'></div>
# <div id='f111539b-01a9-4358-bb32-d26121150fa0'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-afa470490262> in <cell line: 1>()
# ----> 1 deeplabcut.plot_trajectories(config_file,videofile_path)
#
# /usr/local/lib/python3.10/dist-packages/deeplabcut/utils/plotting.py in plot_trajectories(config, videos, videotype, shuffle, trainingsetindex, filtered, displayedbodyparts, displayedindividuals, showfigures, destfolder, modelprefix, imagetype, resolution, linewidth, track_method)
#     300             )
#     301             tmpfolder = os.path.join(videofolder, "plot-poses", vname)
# ...
